# %% [markdown]
# # Groupby

# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.2.0.tar.gz (281.3 MB)
#      |████████████████████████████████| 281.3 MB 34 kB/s
# Collecting py4j==0.10.9.2
#   Downloading py4j-0.10.9.2-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 60.8 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.2.0-py2.py3-none-any.whl size=281805911 sha256=a5d6f165516cabad692edc1825fc3075a981394c071055c3ee07c7def797b663
#   Stored in directory: /root/.cache/pip/wheels/0b/de/d2/9be5d59d7331c6c2a7c1b6d1a4f463ce107332b1ecd4e80718
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.2 pyspark-3.2.0

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Aggregation").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://33b11ce83ae1:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Aggregation</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.read.csv("/content/drive/MyDrive/Pyspark/test3.csv", header =True, inferSchema=True)

# %%
df.show()
# Out:
# +---------+------------+------+
# |     Name| Departments|salary|
# +---------+------------+------+
# |    Krish|Data Science| 10000|
# |    Krish|         IOT|  5000|
# |   Mahesh|    Big Data|  4000|
# |    Krish|    Big Data|  4000|
# |   Mahesh|Data Science|  3000|
# |Sudhanshu|Data Science| 20000|
# |Sudhanshu|         IOT| 10000|
# |Sudhanshu|    Big Data|  5000|
# |    Sunny|Data Science| 10000|
# |    Sunny|    Big Data|  2000|
# +---------+------------+------+

# %%
df.groupBy("Name").sum().show()
# Out:
# +---------+-----------+
# |     Name|sum(salary)|
# +---------+-----------+
# |Sudhanshu|      35000|
# |    Sunny|      12000|
# |    Krish|      19000|
# |   Mahesh|       7000|
# +---------+-----------+

# %%
df.groupBy("Departments").mean().show()
# Out:
# +------------+-----------+
# | Departments|avg(salary)|
# +------------+-----------+
# |         IOT|     7500.0|
# |    Big Data|     3750.0|
# |Data Science|    10750.0|
# +------------+-----------+

# %%
df.groupBy("Name").count().show()
# Out:
# +---------+-----+
# |     Name|count|
# +---------+-----+
# |Sudhanshu|    3|
# |    Sunny|    2|
# |    Krish|    3|
# |   Mahesh|    2|
# +---------+-----+

# %%
df.agg({"Salary":"sum"}).show()
# Out:
# +-----------+
# |sum(Salary)|
# +-----------+
# |      73000|
# +-----------+
