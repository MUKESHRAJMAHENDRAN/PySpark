# %%
# !pip install pyspark
# Out:
# ...
#      |████████████████████████████████| 281.3 MB 37 kB/s
# ...
#      |████████████████████████████████| 198 kB 55.3 MB/s
# ...
#   Created wheel for pyspark: filename=pyspark-3.2.0-py2.py3-none-any.whl size=281805911 sha256=46ec29a6252ec009602a1c4c21868f2f93010e94d3513223ee198e245bb2bcad
#   Stored in directory: /root/.cache/pip/wheels/0b/de/d2/9be5d59d7331c6c2a7c1b6d1a4f463ce107332b1ecd4e80718
# Successfully built pyspark
# ...

# %%
import pyspark
pyspark.__version__
# Out:
# '3.2.0'

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Learning").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://ce5b9f306186:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Learning</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.read.option("header", "true").csv("/content/test1.csv", inferSchema = True)

# %%
df.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
type(df)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)
#  |-- Salary: integer (nullable = true)

# %%
df.head(3)
# Out:
# [Row(Name='Krish', age=31, Experience=10, Salary=30000),
#  Row(Name='Sudhanshu', age=30, Experience=8, Salary=25000),
#  Row(Name='Sunny', age=29, Experience=4, Salary=20000)]

# %%
df.select(["Name", "Age"]).show()
# Out:
# +---------+---+
# |     Name|Age|
# +---------+---+
# |    Krish| 31|
# |Sudhanshu| 30|
# |    Sunny| 29|
# |     Paul| 24|
# |   Harsha| 21|
# |  Shubham| 23|
# +---------+---+

# %%
df.dtypes
# Out:
# [('Name', 'string'), ('age', 'int'), ('Experience', 'int'), ('Salary', 'int')]

# %%
df["Name"]
# Out:
# Column<'Name'>

# %%
df.describe().show()
# Out:
# +-------+------+------------------+-----------------+------------------+
# |summary|  Name|               age|       Experience|            Salary|
# +-------+------+------------------+-----------------+------------------+
# |  count|     6|                 6|                6|                 6|
# |   mean|  null|26.333333333333332|4.666666666666667|21333.333333333332|
# | stddev|  null| 4.179314138308661|3.559026084010437| 5354.126134736337|
# |    min|Harsha|                21|                1|             15000|
# |    max| Sunny|                31|               10|             30000|
# +-------+------+------------------+-----------------+------------------+

# %%
df.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
#Adding a column
df = df.withColumn("Salary after 5 years",df["Salary"]+10000)

# %%
df.show()
# Out:
# +---------+---+----------+------+--------------------+
# |     Name|age|Experience|Salary|Salary after 5 years|
# +---------+---+----------+------+--------------------+
# |    Krish| 31|        10| 30000|               40000|
# |Sudhanshu| 30|         8| 25000|               35000|
# |    Sunny| 29|         4| 20000|               30000|
# |     Paul| 24|         3| 20000|               30000|
# |   Harsha| 21|         1| 15000|               25000|
# |  Shubham| 23|         2| 18000|               28000|
# +---------+---+----------+------+--------------------+

# %%
#Now we are going to rename a column
df = df.withColumnRenamed("Name", "Employee_name")

# %%
df.show()
# Out:
# +-------------+---+----------+------+--------------------+
# |Employee_name|age|Experience|Salary|Salary after 5 years|
# +-------------+---+----------+------+--------------------+
# |        Krish| 31|        10| 30000|               40000|
# |    Sudhanshu| 30|         8| 25000|               35000|
# |        Sunny| 29|         4| 20000|               30000|
# |         Paul| 24|         3| 20000|               30000|
# |       Harsha| 21|         1| 15000|               25000|
# |      Shubham| 23|         2| 18000|               28000|
# +-------------+---+----------+------+--------------------+

# %%
#Deleting a column
df = df.drop("Salary after 5 years")

# %%
df.show()
# Out:
# +-------------+---+----------+------+
# |Employee_name|age|Experience|Salary|
# +-------------+---+----------+------+
# |        Krish| 31|        10| 30000|
# |    Sudhanshu| 30|         8| 25000|
# |        Sunny| 29|         4| 20000|
# |         Paul| 24|         3| 20000|
# |       Harsha| 21|         1| 15000|
# |      Shubham| 23|         2| 18000|
# +-------------+---+----------+------+
